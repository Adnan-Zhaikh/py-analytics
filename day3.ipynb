# %%
raw_temperature = [22.5, 104.2, 23.1, -150.0, 24.8, 302.1, 21.9]

print("Raw Dataset: ", raw_temperature)
# Out:
# Raw Dataset:  [22.5, 104.2, 23.1, -150.0, 24.8, 302.1, 21.9]

# %%
clean_temperatures = [t for t in raw_temperature if t > -50.0 & t < 100.0]

print(clean_temperatures)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 clean_temperatures = [t for t in raw_temperature if raw_temperature > -50.0 & raw_temperature < 100.0]
#       2
#       3 print(clean_temperatures)
#
# TypeError: unsupported operand type(s) for &: 'float' and 'list'
