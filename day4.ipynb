# %%
import numpy as np
# dataset of warehoouse product dimension in centimeteres
raw_dimension = np.array([12.5,45.0,62.8,10.9,124.2])

print("Original Vector Type: ", type(raw_dimension))
print("Original Dimension: ", raw_dimension)
# Out:
# Original Vector Type:  <class 'numpy.ndarray'>
# Original Dimension:  [ 12.5  45.   62.8  10.9 124.2]

# %%
scaled_dimension = raw_dimension * 10

print(scaled_dimension)
# Out:
# [ 125.  450.  628.  109. 1242.]
