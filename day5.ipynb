# %%
import numpy as np

stock_levels = np.array([48,20,66,8,100,60])

print("Current Stock: ", stock_levels)
# Out:
# Current Stock:  [ 48  20  66   8 100  60]

# %%
low_stock_mask = stock_levels <= 15
print(low_stock_mask)

critical_items = stock_levels[low_stock_mask]
print(critical_items)
# Out:
# [False False False  True False False]
# [8]
