# %%
import pandas as pd
raw_data = {
    "Employee": ["Adnan", "Addy", "Billa", "Sahi"],
    "Department": ["Engineering", "Design", "Data Science", "Engineering"],
    "ProjectsCompleted": [12, 5, 9, 3],
    "IsActive": [True, True, False, True]
}
df = pd.DataFrame(raw_data)
print(df)

print(df["Department"])
# Out:
#   Employee    Department  ProjectsCompleted  IsActive
# 0    Adnan   Engineering                 12      True
# 1     Addy        Design                  5      True
# 2    Billa  Data Science                  9     False
# 3     Sahi   Engineering                  3      True
